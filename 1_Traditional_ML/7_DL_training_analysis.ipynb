# %%
import glob
import os
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
sns.set( style="ticks" )
sns.set(rc={'figure.figsize':(11.7,8.27)})

def draw(pth):
    df_1 = pd.read_csv("src/data/1_dataset_elec.csv", index_col=0)
    df_2 = pd.read_csv("src/data/3_dataset_outlier_elec.csv", index_col=0)

    true_path = "src/training_best/" + str(pth) + ".csv"
    # ----- select -----
    df_pred = np.loadtxt(true_path, delimiter=',')
    df_selected = df_1.copy()
    df_selected = df_2.copy()
    df_selected = df_selected.reset_index()

    # ----- end -----

    l = len(df_pred)
    x = np.arange(0, l)
    y_true = []
    y_pred = df_pred

    for idx in range(7, l+7):
        y_true.append( df_selected['OR'][idx] )



    fig, ax = plt.subplots()
    sns.lineplot(x=x, y=y_true, ax=ax)
    sns.lineplot(x=x, y=y_pred, ax=ax)

# %% [markdown]
# ## LSTM_05 results

# %%
draw("7_LSTM_05_train_epoch50_7days")

# %%
draw("7_LSTM_05_train_epoch50_7days_pred")

# %% [markdown]
# # BLSTM_05

# %%
draw("8_BLSTM_05_pred_epoch50_7days")

# %%
draw("8_BLSTM_05_pred_epoch50_7days_pred")

# %% [markdown]
# ## LSTM overfitting version

# %%
draw("7_LSTM_05_train_epoch50_7days")

# %%
draw("7_LSTM_05_train_epoch50_7days")

# %%
draw("7_LSTM_05_train_epoch50_7days")

# %%
draw("7_LSTM_05_train_epoch50_7days")

# %% [markdown]
# # Underfitted Situation

# %%
draw("7_LSTM_05_train_epoch50_7days")
